# %% [markdown]
# - [x] [Threading: Run Code Concurrently Using the Threading Module](https://youtu.be/IEEhzQoKtQU)

# %%
import concurrent.futures as cf
import time

start = time.perf_counter()

def do_something(duration):
    print(f'sleeping {duration} second(s)...')
    time.sleep(duration)
    return 'waking up...' 

with cf.ThreadPoolExecutor(max_workers=100) as executor:
    results = [executor.submit(do_something, 1.5) for _ in range(100)]

    for f in cf.as_completed(results):
        print(f.result())

finish = time.perf_counter()

print(f'Finished in {round(finish-start, 2)} second(s)')

# 100 tasks
# Finished in 1.52 second(s)
# Out:
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...sleeping 1.5 second(s)...
#
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...sleeping 1.5 second(s)...
#
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# sleeping 1.5 second(s)...
# ...
