# %%
# Raw Package
import numpy as np
import pandas as pd

# %%
#Data Source
import yfinance as yf

# %%
#Data viz
import plotly.graph_objs as go

# %%
data = yf.download(tickers='BTC-USD',period = '3mo', interval = '1d')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2020-11-07  15565.880859  15737.095703  14423.203125  14833.753906
# 2020-11-08  14833.753906  15637.320312  14744.110352  15479.567383
# 2020-11-09  15479.595703  15785.136719  14865.529297  15332.315430
# 2020-11-10  15332.350586  15450.329102  15124.959961  15290.902344
# 2020-11-11  15290.909180  15916.260742  15290.006836  15701.339844
# ...                  ...           ...           ...           ...
# 2021-02-03  35510.820312  37480.187500  35443.984375  37472.089844
# 2021-02-04  37475.105469  38592.175781  36317.500000  36926.066406
# 2021-02-05  36931.546875  38225.906250  36658.761719  38144.308594
# 2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 2021-02-07  38989.117188  39620.664062  37446.152344  38552.238281
#
#                Adj Close       Volume
# Date
# 2020-11-07  14833.753906  35024953706
# ...

# %%
data['MA5'] = data['Close'].rolling(5).mean()
data['MA20'] = data['Close'].rolling(20).mean()

# %%
#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

fig.add_trace(go.Scatter(x=data.index, y= data['MA20'],line=dict(color='red', width=1.5), name = 'Moving Average'))
fig.add_trace(go.Scatter(x=data.index, y= data['MA5'],line=dict(color='blue', width=1.5), name = 'Moving Average'))

fig.update_layout(
    yaxis_title='BTC/USD (kUS Dollars)')

#Show
fig.show()
# Out:
# <div>
#
#
#             <div id="b8a7c1f7-bbe4-4d68-9930-a8b5cab8bffb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b8a7c1f7-bbe4-4d68-9930-a8b5cab8bffb")) {
#                     Plotly.newPlot(
#                         'b8a7c1f7-bbe4-4d68-9930-a8b5cab8bffb',
# ...
